# %% [markdown]
# <h2>Agregando dados </p> <h5>Métodos de agregação, ou agg, permitem calcular estatísticas personalizadas.

# %%
import pandas as pd
import numpy as np
carros = pd.read_csv("carros.csv")

# %%
carros.head(3)
# Out:
#          Região   Estado  Quant Carros  Quant Carros Família com Filhos  \
# 0           Sul     Acre          4342                             1034
# 1  Centro-Oeste  Alagoas         18991                             3253
# 2       Sudeste    Amapá          6463                             4152
#
#    População do Estado  Carros por habitante
# 0              23942.0              0.181355
# 1              23431.0              0.810507
# 2               7747.0              0.834258

# %% [markdown]
# Quantile = calcula o q-ésimo quantil dos dados ao longo do eixo especificado.

# %%
#agregando um cáculo com uma função
def pct50(coluna):
    return coluna.quantile(0.50) #Quantile com numpy

carros['Quant Carros'].agg(pct50)
# Out:
# 8472.0

# %%
def max_min(coluna):
    return coluna.max(), coluna.min()

carros['Quant Carros'].agg(max_min)
# Out:
# (33848, 2241)

# %% [markdown]
# O pandas também possui métodos para calcular estatísticas cumulativas. Chamar "cumsum" em uma coluna não retonra apenas um número, mas um número para cada linha do DataFrame. </p> O primeiro número retornado é a quantidade do primeiro carro, o segundo é a soma do primeiro com o segundo, e assim sucessivamente. O último é a soma de todos.

# %%
carros['Quant Carros'].cumsum()
# Out:
# 0       4342
# 1      23333
# 2      29796
# 3      32976
# 4      44264
# 5      55071
# 6      60857
# 7      66351
# 8      90763
# 9      99235
# 10    104103
# 11    109786
# 12    127077
# 13    149464
# 14    160130
# 15    166166
# 16    176699
# 17    184611
# 18    218459
# 19    224855
# 20    227096
# 21    250209
# 22    253770
# 23    263236
# 24    269553
# 25    291860
# 26    309004
# Name: Quant Carros, dtype: int64

# %% [markdown]
# <b>Excluindo duplicados:</b> drop_duplicates </p> Permite a criação de um novo DataFrame sem repetições com base em critérios específicos. O subset define qual coluna deve ser feita a operação.

# %%
carros.drop_duplicates(subset='Região')
# Out:
#           Região          Estado  Quant Carros  \
# 0            Sul            Acre          4342
# 1   Centro-Oeste         Alagoas         18991
# 2        Sudeste           Amapá          6463
# 5       Nordeste           Ceará         10807
# 18         Norte  Rio de Janeiro         33848
#
#     Quant Carros Família com Filhos  População do Estado  Carros por habitante
# 0                              1034              23942.0              0.181355
# 1                              3253              23431.0              0.810507
# 2                              4152               7747.0              0.834258
# 5                              4943              40773.0              0.265053
# 18                             2579              48323.0              0.700453

# %% [markdown]
# <b>Groupby com Agg:</b> groupby faz um agrupamento de uma ou mais colunas, permitindo a aplicação de operações por grupo, que podem ser usadas com outros métodos agg para cáclulos estatísticos.

# %%
carros.groupby('População do Estado')['Carros por habitante'].agg(max_min)
# Out:
# População do Estado
# 5189.0     (0.6128348429369821, 0.6128348429369821)
# 6267.0     (0.8766554970480294, 0.8766554970480294)
# 6899.0       (0.838672271343673, 0.838672271343673)
# 7612.0     (0.8298738833420914, 0.8298738833420914)
# 7747.0     (0.8342584226152059, 0.8342584226152059)
# 8556.0     (0.5689574567554933, 0.5689574567554933)
# 8890.0     (0.6392575928008999, 0.6392575928008999)
# 13433.0    (0.1668279609915879, 0.1668279609915879)
# 13792.0    (0.5736658932714617, 0.5736658932714617)
# 15627.0    (0.6740257247072374, 0.6740257247072374)
# 16016.0    (0.2223401598401598, 0.2223401598401598)
# 16394.0    (0.5167744296693912, 0.5167744296693912)
# 19502.0    (0.5469182647933545, 0.5469182647933545)
# 22159.0        (0.77368112279435, 0.77368112279435)
# 23431.0    (0.8105074473987453, 0.8105074473987453)
# 23942.0    (0.1813549411076769, 0.1813549411076769)
# 24118.0    (0.4680321751389004, 0.4680321751389004)
# 26777.0    (0.2254173357732382, 0.2254173357732382)
# 28483.0    (0.7831689077695467, 0.7831689077695467)
# 28897.0    (0.3275772571547219, 0.3275772571547219)
# 35740.0    (0.6263850027979855, 0.6263850027979855)
# 36551.0    (0.6678887034554458, 0.6678887034554458)
# 40773.0    (0.2650528536041007, 0.2650528536041007)
# 46606.0    (0.3710037334248809, 0.3710037334248809)
# 48001.0    (0.4815108018582946, 0.4815108018582946)
# 48021.0    (0.1331917286187293, 0.1331917286187293)
# 48323.0    (0.7004532003393829, 0.7004532003393829)
# Name: Carros por habitante, dtype: object

# %% [markdown]
# <b>Tabelas Pivot:</b> Cálculos estatísticos resumidas e agrupadas.

# %%
grupo = carros.groupby('População do Estado')['Carros por habitante']
carros.pivot_table(values='População do Estado',index='Carros por habitante')
# Out:
#                       População do Estado
# Carros por habitante
# 0.133192                          48021.0
# 0.166828                          13433.0
# 0.181355                          23942.0
# 0.222340                          16016.0
# 0.225417                          26777.0
# 0.265053                          40773.0
# 0.327577                          28897.0
# 0.371004                          46606.0
# 0.468032                          24118.0
# 0.481511                          48001.0
# 0.516774                          16394.0
# 0.546918                          19502.0
# 0.568957                           8556.0
# 0.573666                          13792.0
# 0.612835                           5189.0
# 0.626385                          35740.0
# 0.639258                           8890.0
# 0.667889                          36551.0
# 0.674026                          15627.0
# 0.700453                          48323.0
# 0.773681                          22159.0
# 0.783169                          28483.0
# 0.810507                          23431.0
# 0.829874                           7612.0
# 0.834258                           7747.0
# 0.838672                           6899.0
# 0.876655                           6267.0

# %% [markdown]
# <b>Aggfunc:</b> Argumento para passar funções.

# %%
carros.pivot_table(values='População do Estado',index='Carros por habitante',aggfunc=np.median)
# Out:
# C:\Users\Lua.LUADESKTOP\AppData\Local\Temp\ipykernel_1276\4166756064.py:1: FutureWarning: The provided callable <function median at 0x00000187738539C0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   carros.pivot_table(values='População do Estado',index='Carros por habitante',aggfunc=np.median)
#                       População do Estado
# Carros por habitante
# 0.133192                          48021.0
# 0.166828                          13433.0
# 0.181355                          23942.0
# 0.222340                          16016.0
# 0.225417                          26777.0
# 0.265053                          40773.0
# 0.327577                          28897.0
# 0.371004                          46606.0
# 0.468032                          24118.0
# 0.481511                          48001.0
# 0.516774                          16394.0
# 0.546918                          19502.0
# 0.568957                           8556.0
# 0.573666                          13792.0
# 0.612835                           5189.0
# 0.626385                          35740.0
# 0.639258                           8890.0
# 0.667889                          36551.0
# 0.674026                          15627.0
# 0.700453                          48323.0
# 0.773681                          22159.0
# 0.783169                          28483.0
# 0.810507                          23431.0
# 0.829874                           7612.0
# 0.834258                           7747.0
# 0.838672                           6899.0
# 0.876655                           6267.0

# %% [markdown]
# <b>Pivot de várias variáveis:</b> Passa um segundo nome de variável para ver o agrupamento, com os valores em comun que aparecem de acordo com o parâmetro.

# %%
carros.pivot_table(values='População do Estado',index='Carros por habitante',columns='Região')
# Out:
# Região                Centro-Oeste  Nordeste    Norte  Sudeste      Sul
# Carros por habitante
# 0.133192                       NaN       NaN      NaN      NaN  48021.0
# 0.166828                       NaN   13433.0      NaN      NaN      NaN
# 0.181355                       NaN       NaN      NaN      NaN  23942.0
# 0.222340                       NaN       NaN      NaN      NaN  16016.0
# 0.225417                       NaN   26777.0      NaN      NaN      NaN
# 0.265053                       NaN   40773.0      NaN      NaN      NaN
# 0.327577                       NaN       NaN  28897.0      NaN      NaN
# 0.371004                   46606.0       NaN      NaN      NaN      NaN
# 0.468032                   24118.0       NaN      NaN      NaN      NaN
# 0.481511                   48001.0       NaN      NaN      NaN      NaN
# 0.516774                   16394.0       NaN      NaN      NaN      NaN
# 0.546918                       NaN       NaN      NaN      NaN  19502.0
# 0.568957                       NaN       NaN      NaN      NaN   8556.0
# 0.573666                   13792.0       NaN      NaN      NaN      NaN
# 0.612835                    5189.0       NaN      NaN      NaN      NaN
# 0.626385                       NaN   35740.0      NaN      NaN      NaN
# 0.639258                       NaN       NaN      NaN   8890.0      NaN
# 0.667889                       NaN       NaN      NaN  36551.0      NaN
# 0.674026                       NaN       NaN      NaN      NaN  15627.0
# 0.700453                       NaN       NaN  48323.0      NaN      NaN
# 0.773681                       NaN       NaN      NaN  22159.0      NaN
# 0.783169                       NaN       NaN      NaN  28483.0      NaN
# 0.810507                   23431.0       NaN      NaN      NaN      NaN
# 0.829874                       NaN       NaN   7612.0      NaN      NaN
# 0.834258                       NaN       NaN      NaN   7747.0      NaN
# 0.838672                       NaN       NaN      NaN   6899.0      NaN
# 0.876655                       NaN       NaN      NaN   6267.0      NaN

# %% [markdown]
# <b>Substituir valores faltosos:</b> Argumento margins cria uma útlima linha com última coluna "All" que contém a média de todos os valores na coluna ou linha, excluindo os valores ausentes que foram preenchidos com zeros.

# %%
carros.pivot_table(values='População do Estado',index='Região',fill_value=0,margins=True)
# Out:
#               População do Estado
# Região
# Centro-Oeste         25361.571429
# Nordeste             29180.750000
# Norte                28277.333333
# Sudeste              16713.714286
# Sul                  21944.000000
# All                  23249.851852

# %% [markdown]
# <h3>Indexação e Fatiamento

# %% [markdown]
# <b>Reset_index:</b> Remover um índice e voltar as definições padrões do DataFrame.

# %%
#carros.reset_index(drop=True)

# %% [markdown]
# <b>Buscas e filtragem:</b> O loc facilita para localizar os dataframes, mas depende do índice.

# %%
carros[carros['Estado'].isin(['Paraná','Pernambuco'])]
#faz uma busca por coluna
# Out:
#       Região      Estado  Quant Carros  Quant Carros Família com Filhos  \
# 15  Nordeste      Paraná          6036                             1702
# 16       Sul  Pernambuco         10533                             3449
#
#     População do Estado  Carros por habitante
# 15              26777.0              0.225417
# 16              15627.0              0.674026

# %% [markdown]
# <b>Sort_index:</b> Controlar a ordenação com ascendencia ou descendência. </p> índices são controversos, a sintaxe para trabalhar com índices é diferente da sintaxe para trabalhar com colunas.

# %% [markdown]
# <h3>Slicing

# %% [markdown]
# Técnica para selecionar os elementos consecutivos de objetos. cortando DataFrames ordenando os índices. Ele mantem a contagem total dos valores mesmo sendo duplicados.

# %% [markdown]
# <b>Slice de Colunas:</b> Como os  DataFrames são objetos bidimensionais, podemos cortar colunas mas mantendo todas as linhas.

# %%
carros.loc[:,'Região':'Estado']
# Out:
#           Região               Estado
# 0            Sul                 Acre
# 1   Centro-Oeste              Alagoas
# 2        Sudeste                Amapá
# 3   Centro-Oeste             Amazonas
# 4   Centro-Oeste                Bahia
# 5       Nordeste                Ceará
# 6        Sudeste     Distrito Federal
# 7        Sudeste       Espírito Santo
# 8        Sudeste                Goiás
# 9   Centro-Oeste             Maranhão
# 10           Sul          Mato Grosso
# 11       Sudeste   Mato Grosso do Sul
# 12  Centro-Oeste         Minas Gerais
# 13      Nordeste                 Pará
# 14           Sul              Paraíba
# 15      Nordeste               Paraná
# 16           Sul           Pernambuco
# 17  Centro-Oeste                Piauí
# 18         Norte       Rio de Janeiro
# 19           Sul  Rio Grande do Norte
# 20      Nordeste    Rio Grande do Sul
# 21  Centro-Oeste             Rondônia
# 22           Sul              Roraima
# 23         Norte       Santa Catarina
# 24         Norte            São Paulo
# 25       Sudeste              Sergipe
# 26       Sudeste            Tocantins

# %% [markdown]
# Cortando linhas e Colunas

# %%
carros.loc[('Norte'):'Quant Carros']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 carros.loc[carros('Norte'):'Quant Carros']
#
# TypeError: 'DataFrame' object is not callable
